# %%
class calc():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
        
    def addition(num1, num2):
        print(f'Addition= {num1+num2}')
        
    def subtraction(num1, num2):
        print(f'Subtraction= {num1-num2}')
    
    def division(num1, num2):
        print(f'Division= {num1/num2}')
    
    def multiplication(num1, num2):
        print(f'Multiplication= {num1*num2}')
    
    def exponent(num1, num2):
        print(f'Exponent= {num1**num2}')
        
    def square_root():
        import math
        print(f'Square root= {math.sqrt(num1)}')
    
    def rectangle_area(num1,num2):
        print(f'Area of a Rectangle= {num1*num2}')
        
    def rectangle_perimeter(num1,num2):
        print(f'Perimeter of a Rectangle= {num1*2+num2*2}')
        
    def circle_area(num1):
        import math
        print(f'Area of a Circle= {math.pi*num1**2}')
    
    def circle_perimeter(num1):
        import math
        print(f'Perimeter of a Circle= {2*math.pi*num1}')
        
    def triangle_area(num1,num2):
        print(f'Area of a Triangle= {(num1*num2)/2}')
        
    def triangle_perimeter(num1,num2,num3):
        print(f'Perimeter of a Triangle= {num1+num2+num3}')
    
    def average(num1,num2):
        print(f'Average of 2 Numbers= {(num1+num2)/2}')
    
    def percentage(num1,num2):
        print(f'Percentage of Total= {(num2/num1)*100}')
        
    def pythag(num1,num2):
        import math
        print(f'Pythagorean Theorm= {math.sqrt(num1**2+num2**2)}')

while True:
    print()
    print("Chose from the following menu:")
    print()
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exponent")
    print("6. Square Root")
    print("7. Area of Rectangle")
    print("8. Perimeter of Rectangle")
    print("9. Area of a circle")
    print("10. Perimeter of a circle")
    print("11. Area of a Triangle")
    print("12. Perimeter of a Triangle")
    print("13. Average between Numbers")
    print("14. Percentage")
    print("15. Pythagorean Theorem")
    print("16. Exit")
    print()
    
    
    choice=int(input("Enter your choice (1-16) "))
    
    if choice==1:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        calc.addition(num1,num2)
    elif choice==2:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        calc.subtraction(num1,num2)
    elif choice==3:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        calc.multiplication(num1,num2)
    elif choice==4:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        if num2==0:
            print("Infinity")
        else:
            calc.division(num1,num2)
    elif choice==5:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        if num2==0:
            print("1")
        else:
            calc.exponent(num1,num2)
    elif choice==6:
        num1=int(input("Enter the number:"))
        calc.square_root()
    elif choice==7:
        num1=int(input("Enter the length:"))
        num2=int(input("Enter the width:"))
        calc.rectangle_area(num1,num2)
    elif choice==8:
        num1=int(input("Enter the length:"))
        num2=int(input("Enter the width:"))
        calc.rectangle_perimeter(num1,num2)
    elif choice==9:
        num1=int(input("Enter the radius:"))
        calc.circle_area(num1)
    elif choice==10:
        num1=int(input("Enter the radius:"))
        calc.circle_perimeter(num1)
    elif choice==11:
        num1=int(input("Enter the base:"))
        num2=int(input("Enter the height:"))
        calc.triangle_area(num1,num2)
    elif choice==12:
        num1=int(input("Enter the first side:"))
        num2=int(input("Enter the second side:"))
        num3=int(input("Enter the third side:"))
        calc.triangle_perimeter(num1,num2,num3)
    elif choice==13:
        num1=int(input("Enter 1st number:"))
        num2=int(input("Enter 2nd number:"))
        calc.average(num1,num2)
    elif choice==14:
        num1=int(input("Enter the total value:"))
        num2=int(input("Enter part of the total value:"))
        calc.percentage(num1,num2)
    elif choice==15:
        num1=int(input("Enter the height:"))
        num2=int(input("Enter the width:"))
        calc.pythag(num1,num2)
                 
    elif choice==16:
        break
    else:
        print("This isn't an option")
# Out:
# Chose from the following menu:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponent
# 6. Square Root
# 7. Area of Rectangle
# 8. Perimeter of Rectangle
# 9. Area of a circle
# 10. Perimeter of a circle
# 11. Area of a Triangle
# 12. Perimeter of a Triangle
# 13. Average between Numbers
# 14. Percentage
# 15. Pythagorean Theorem
# 16. Exit
#
# Enter your choice (1-16) 10
# Enter the radius:2
# Perimeter of a Circle= 12.566370614359172
#
# Chose from the following menu:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponent
# 6. Square Root
# 7. Area of Rectangle
# 8. Perimeter of Rectangle
# 9. Area of a circle
# 10. Perimeter of a circle
# 11. Area of a Triangle
# 12. Perimeter of a Triangle
# 13. Average between Numbers
# 14. Percentage
# 15. Pythagorean Theorem
# 16. Exit

# %% [markdown]
# # Ben Griffis
# ## PA6
# ## CS-150 Fall
# ## V1
